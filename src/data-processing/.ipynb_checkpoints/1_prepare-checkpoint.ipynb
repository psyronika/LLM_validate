# %% [markdown]
# ## Prepare data for LLM annotations
#
# This notebook takes in the Dutch election data as input, cleans it, removes unrelated cases. Then it takes a random 3-day sample for the purpose of validating the validation scheme. It then gets the lead and title of articles,extract proper nouns, and keywords, and finally it creates text pairs based on cosine similarity.
#
# * **input**: csv with documents
# * **output**: sample of original csv/pickle file, text-pairs enriched with proper nouns, keywords, cosine similarity score
# * **embedding model used**: **GroNLP/bert-base-dutch-cased**

# %%
#import packages
import pandas as pd
import torch
from transformers import BertTokenizer, BertModel
from tqdm import tqdm
import pickle
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from itertools import combinations
import spacy
import re
import matplotlib.pyplot as plt

# %%
#read in the data
filename = 'newspaper_data/Dutch_election_data (1).csv'
try:
    df = pd.read_csv(filename)
except pd.errors.ParserError as e:
    print(e)
    print('Printing rows until the error is encountered:')
    with open(filename, 'r') as f:
        for i, line in enumerate(f):
            if i > e.row:
                break
            print(f"{i}: {line}")

# %%
#sort by date
df = df.sort_values(by = 'date')

# Get the number of unique dates
num_unique_dates = len(df['date'].unique())
num_unique_publishers = len(df['publisher'].unique())

# Print the result using an f-string
print(f"There are {num_unique_dates} dates in the DataFrame across {num_unique_publishers} publishers in the Netherlands. ")
# Out:
# There are 1597 dates in the DataFrame across 10 publishers in the Netherlands.

# %%
#get unique publishers
df['publisher'].unique()
# Out:
# array(['De Telegraaf', 'NRC Handelsblad', 'Het Financieele Dagblad',
#        'Trouw', 'Algemeen Dagblad', 'De Volkskrant', 'NU.nl', 'Nieuwsuur',
#        'NOS nieuws', 'NOS liveblog'], dtype=object)

# %%
# Check for missing values in the 'text' column
missing_values = df['text'].isnull()

# Delete rows with missing values in the 'text' column
df = df[~missing_values]

# %%
#exclude texts that are recommendations for tv programs of news in short or a list of tips
#these often have non unique titles such as 'Tips'

# Find non-unique titles
non_unique_titles = df['title'][df['title'].duplicated(keep=False)]

# Print non-unique titles
print('Non-unique titles:')
print(len(non_unique_titles.unique()))

#print(non_unique_titles.unique())

#after manual observationexclude those rows where the title matches one of the below common headlines.

#remove all rows where title is just the program for some channels  
to_remove = ['NPO 2', 'NPO 1' ,'BBC 1' , 'BBC 2','TLC', 'Tips','kop tag with dummy text', 'Film- en televisietips', 'tv-ladder', 'TV-ladder', 'Best gelezen op fd.nl', 'MEER LEZEN']
# Out:
# Non-unique titles:
# 244

# %%
# Exclude rows with titles in the list
df= df[~df['title'].isin(to_remove)]

# %%
# Calculate text lengths
df['text_length'] = df['text'].astype(str).apply(len)
#get average length of text 
#Print the result using an f-string
average_text_length = df['text_length'].mean()
print(f"The average text length in this dataset of news articles is {average_text_length} characters.")
# Out:
# The average text length in this dataset of news articles is 3786.6435627530363 characters.

# %%
# Create a histogram
plt.hist(df['text_length'], bins=100, edgecolor='black')

plt.title('Text Length Histogram')
plt.xlabel('Text Length')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# ### Take a random sample of the full dataset
#
# This is a candidate sample of information flows. In absense of an already annotated dataset, we get our candidate sample based on cosine similarity which was established as a good indicator of matches.

# %%
df['date'] = pd.to_datetime(df['date'])  # Convert to datetime format
df_resampled = df.resample('D', on='date').count()

# Calculate the average number of articles
average_articles = df_resampled['id'].mean()

# Find the time point(s) closest to the average
closest_time_points = df_resampled.loc[df_resampled['id'].sub(average_articles).abs().idxmin()]

# Visualize the data with average line
plt.figure(figsize=(10, 6))
plt.plot(df_resampled.index, df_resampled['id'], marker='o', label='Published Articles')
plt.axhline(y=average_articles, color='r', linestyle='--', label='Average Articles Published')
plt.title('Number of Published Articles Over Days')
plt.xlabel('Time')
plt.ylabel('Number of Articles')
plt.legend()
plt.grid(True)
plt.tight_layout()  # Ensures labels are not cut off
plt.show()
# Save the plot as a PDF file
plt.savefig('figures/published_articles_plot.pdf')

print("Average number of articles:", average_articles)
print("Time point(s) closest to average:", closest_time_points.name)
# Out:
# Average number of articles: 81.25
# Time point(s) closest to average: 2021-02-24 00:00:00

# %%
import statsmodels.api as sm

# Perform decomposition
decomposition = sm.tsa.seasonal_decompose(df_resampled['id'], model='multiplicative')

# Plot the decomposition components
plt.figure(figsize=(10, 8))
plt.subplot(4, 1, 1)
plt.plot(df_resampled.index, df_resampled['id'], color='b',label='Original')
plt.legend(loc='upper left')
plt.subplot(4, 1, 2)
plt.plot(decomposition.trend, color='b',label='Trend')
plt.legend(loc='upper left')
plt.subplot(4, 1, 3)
plt.plot(decomposition.seasonal, color='b',label='Seasonality')
plt.legend(loc='upper left')
plt.subplot(4, 1, 4)
plt.scatter(df_resampled.index, decomposition.resid, label='Residuals', color='b', marker='o')
plt.axhline(y=0, color='r', linestyle='--', label='Zero Line')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
import random
from datetime import timedelta, datetime

# Set the random seed for reproducibility
random.seed(1234567)

# Assuming you have already imported and have a DataFrame 'df'

# Convert the 'date' column to datetime if it's not already
df['date'] = pd.to_datetime(df['date'])

# Get the list of unique dates in the DataFrame
unique_dates = df['date'].unique()

# Randomly select a starting date for the 3-day window
random_start_date = random.choice(unique_dates)

# Calculate the corresponding ending date
random_end_date = random_start_date + timedelta(days=2)

# Filter the DataFrame for rows within the randomly selected 3-day window
df1 = df[(df['date'] >= random_start_date) & (df['date'] <= random_end_date)]

# %%
df1
# Out:
#            id     publisher  \
# 3864  3287580     Nieuwsuur
# 3851  3287538  NOS liveblog
# 3850  3287537  NOS liveblog
# 3849  3287536  NOS liveblog
# 3848  3287535  NOS liveblog
# ...       ...           ...
# 6023  6290506  NOS liveblog
# 3807  3287398  NOS liveblog
# 6041  6290581    NOS nieuws
# 6022  6290505  NOS liveblog
# 3806  3287397  NOS liveblog
#
#                                                                                                     title  \
# 3864  De uitzending van 27 februari: Verkiezingsspecial: in gesprek met Thierry Baudet / Corona-uitbra...
# 3851                                                                     Ziekenhuisbezetting daalt met 55
# 3850                                                       Eindhoven: kom niet naar de koning op 27 april
# 3849                                  FvD'ers houden afstand in Oss, maar ondernemers voelen toch ongemak
# 3848                                                                      D66 pleit voor vaccinatiebewijs
# ...                                                                                                   ...
# 6023                                            'Opvallend en veelzeggend dat VVD en CDA hier niet staan'
# 3807                                            'Opvallend en veelzeggend dat VVD en CDA hier niet staan'
# 6041                             Podcast De Stemming: Verkiezingscampagne maakt nog weinig los bij kiezer
# 6022                               De Jonge: lijsttrekkers moeten in campagne behoedzaam zijn over corona
# 3806                              De Jonge: lijsttrekkers moeten in campagne behoedzaam zijn over corona
#
#      author  \
# 3864    NaN
# 3851    NaN
# 3850    NaN
# 3849    NaN
# 3848    NaN
# ...     ...
# 6023    NaN
# 3807    NaN
# 6041    NaN
# 6022    NaN
# 3806    NaN
#
#                                                                                                      text  \
# 3864  In gesprek met Thierry Baudet\nSaai is het nooit, als het over Forum voor Democratie gaat. De pa...
# 3851  De bezetting in de ziekenhuizen is de afgelopen dag afgenomen. Er lagen in totaal 1809 coronapat...
# 3850  De koning bezoekt dit jaar op zijn verjaardag Eindhoven, in het kader van Koningsdag. De gemeent...
# 3849  Forum voor Democratie-leider Baudet hield vanochtend een verkiezingsbijeenkomst in Oss en haalde...
# 3848  D66-lijsttrekker Sigrid Kaag wil mensen die gevaccineerd zijn meer toegang geven tot het openbar...
# ...                                                                                                   ...
# 6023  Een aantal partijen heeft op een persconferentie gereageerd op de doorrekeningen van het CPB en ...
# 3807  Een aantal partijen heeft op een persconferentie gereageerd op de doorrekeningen van het CPB en ...
# 6041  VVD-lijsttrekker Mark Rutte kwam niet lekker uit het RTL-verkiezingsdebat, constateren Joost Vul...
# 6022  Minister de Jonge van Volksgezondheid vindt het logisch dat lijsttrekkers in de verkiezingscampa...
# 3806  Minister de Jonge van Volksgezondheid vindt het logisch dat lijsttrekkers in de verkiezingscampa...
#
#      Section                date Byline  text_length
# 3864     NaN 2021-02-27 15:06:47    NaN          755
# 3851     NaN 2021-02-27 15:20:11    NaN          397
# 3850     NaN 2021-02-27 15:38:32    NaN          699
# 3849     NaN 2021-02-27 15:58:15    NaN         1020
# 3848     NaN 2021-02-27 16:40:42    NaN         1341
# ...      ...                 ...    ...          ...
# 6023     NaN 2021-03-01 13:15:24    NaN          953
# 3807     NaN 2021-03-01 13:15:24    NaN          953
# 6041     NaN 2021-03-01 13:29:48    NaN         2092
# 6022     NaN 2021-03-01 14:33:22    NaN          871
# 3806     NaN 2021-03-01 14:33:22    NaN          871
#
# [142 rows x 9 columns]

# %% [markdown]
# ### Clean the text

# %%
nlp = spacy.load('nl_core_news_sm')

# %%
def clean_text(text):
    # Apply the Dutch language model
    doc = nlp(text)
    
    # Remove special characters and extra whitespace using regex
    cleaned_tokens = [re.sub(r'[^a-zA-Z0-9.,!?]', ' ', token.text).strip() if token.is_alpha or token.is_punct else token.text for token in doc]
    
    # Join tokens back into cleaned text
    cleaned_text = ' '.join(cleaned_tokens)
    
    # Replace consecutive newline characters with a single space
    cleaned_text = re.sub(r'\n+', ' ', cleaned_text)
    
    # Remove space before common punctuation (except newline)
    cleaned_text = re.sub(r'(?<=[^\n\s])\s*([.,!?])', r'\1', cleaned_text)
    
    # Remove extra spaces
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text)
    
    # Strip leading and trailing spaces
    cleaned_text = cleaned_text.strip()
    
    return cleaned_text

# Apply the cleaning function to the 'text' column with tqdm progress bar
tqdm.pandas()  # Use tqdm with pandas
df1['cleaned_text'] = df1['text'].progress_apply(clean_text)

# Display the cleaned DataFrame
df1
# Out:
# 100%|██████████| 142/142 [00:07<00:00, 20.02it/s]
# /tmp/ipykernel_2650/1061925709.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['cleaned_text'] = df1['text'].progress_apply(clean_text)
#            id     publisher  \
# 3864  3287580     Nieuwsuur
# 3851  3287538  NOS liveblog
# 3850  3287537  NOS liveblog
# 3849  3287536  NOS liveblog
# 3848  3287535  NOS liveblog
# ...       ...           ...
# 6023  6290506  NOS liveblog
# 3807  3287398  NOS liveblog
# 6041  6290581    NOS nieuws
# 6022  6290505  NOS liveblog
# 3806  3287397  NOS liveblog
#
#                                                                                                     title  \
# 3864  De uitzending van 27 februari: Verkiezingsspecial: in gesprek met Thierry Baudet / Corona-uitbra...
# 3851                                                                     Ziekenhuisbezetting daalt met 55
# 3850                                                       Eindhoven: kom niet naar de koning op 27 april
# 3849                                  FvD'ers houden afstand in Oss, maar ondernemers voelen toch ongemak
# 3848                                                                      D66 pleit voor vaccinatiebewijs
# ...                                                                                                   ...
# 6023                                            'Opvallend en veelzeggend dat VVD en CDA hier niet staan'
# 3807                                            'Opvallend en veelzeggend dat VVD en CDA hier niet staan'
# 6041                             Podcast De Stemming: Verkiezingscampagne maakt nog weinig los bij kiezer
# 6022                               De Jonge: lijsttrekkers moeten in campagne behoedzaam zijn over corona
# 3806                              De Jonge: lijsttrekkers moeten in campagne behoedzaam zijn over corona
#
#      author  \
# 3864    NaN
# 3851    NaN
# 3850    NaN
# 3849    NaN
# 3848    NaN
# ...     ...
# 6023    NaN
# 3807    NaN
# 6041    NaN
# 6022    NaN
# 3806    NaN
#
#                                                                                                      text  \
# 3864  In gesprek met Thierry Baudet\nSaai is het nooit, als het over Forum voor Democratie gaat. De pa...
# 3851  De bezetting in de ziekenhuizen is de afgelopen dag afgenomen. Er lagen in totaal 1809 coronapat...
# 3850  De koning bezoekt dit jaar op zijn verjaardag Eindhoven, in het kader van Koningsdag. De gemeent...
# 3849  Forum voor Democratie-leider Baudet hield vanochtend een verkiezingsbijeenkomst in Oss en haalde...
# 3848  D66-lijsttrekker Sigrid Kaag wil mensen die gevaccineerd zijn meer toegang geven tot het openbar...
# ...                                                                                                   ...
# 6023  Een aantal partijen heeft op een persconferentie gereageerd op de doorrekeningen van het CPB en ...
# 3807  Een aantal partijen heeft op een persconferentie gereageerd op de doorrekeningen van het CPB en ...
# 6041  VVD-lijsttrekker Mark Rutte kwam niet lekker uit het RTL-verkiezingsdebat, constateren Joost Vul...
# 6022  Minister de Jonge van Volksgezondheid vindt het logisch dat lijsttrekkers in de verkiezingscampa...
# 3806  Minister de Jonge van Volksgezondheid vindt het logisch dat lijsttrekkers in de verkiezingscampa...
#
#      Section                date Byline  text_length  \
# 3864     NaN 2021-02-27 15:06:47    NaN          755
# 3851     NaN 2021-02-27 15:20:11    NaN          397
# 3850     NaN 2021-02-27 15:38:32    NaN          699
# 3849     NaN 2021-02-27 15:58:15    NaN         1020
# 3848     NaN 2021-02-27 16:40:42    NaN         1341
# ...      ...                 ...    ...          ...
# 6023     NaN 2021-03-01 13:15:24    NaN          953
# 3807     NaN 2021-03-01 13:15:24    NaN          953
# 6041     NaN 2021-03-01 13:29:48    NaN         2092
# 6022     NaN 2021-03-01 14:33:22    NaN          871
# 3806     NaN 2021-03-01 14:33:22    NaN          871
#
#                                                                                              cleaned_text
# 3864  In gesprek met Thierry Baudet Saai is het nooit, als het over Forum voor Democratie gaat. De par...
# 3851  De bezetting in de ziekenhuizen is de afgelopen dag afgenomen. Er lagen in totaal 1809 coronapat...
# 3850  De koning bezoekt dit jaar op zijn verjaardag Eindhoven, in het kader van Koningsdag. De gemeent...
# 3849  Forum voor Democratie-leider Baudet hield vanochtend een verkiezingsbijeenkomst in Oss en haalde...
# 3848  D66-lijsttrekker Sigrid Kaag wil mensen die gevaccineerd zijn meer toegang geven tot het openbar...
# ...                                                                                                   ...
# 6023  Een aantal partijen heeft op een persconferentie gereageerd op de doorrekeningen van het CPB en ...
# 3807  Een aantal partijen heeft op een persconferentie gereageerd op de doorrekeningen van het CPB en ...
# 6041  VVD-lijsttrekker Mark Rutte kwam niet lekker uit het RTL-verkiezingsdebat, constateren Joost Vul...
# 6022  Minister de Jonge van Volksgezondheid vindt het logisch dat lijsttrekkers in de verkiezingscampa...
# 3806  Minister de Jonge van Volksgezondheid vindt het logisch dat lijsttrekkers in de verkiezingscampa...
#
# [142 rows x 10 columns]

# %%
df1['publisher'].unique()
# Out:
# array(['Nieuwsuur', 'NOS liveblog', 'NU.nl', 'NOS nieuws',
#        'Het Financieele Dagblad', 'De Telegraaf', 'Algemeen Dagblad',
#        'Trouw', 'De Volkskrant', 'NRC Handelsblad'], dtype=object)

# %%
#save cleaned data as csv for later usage

df1.to_csv('newspaper_data/cleaned_sample.csv')

# %%
#df1 = pd.read_csv('newspaper_data/cleaned_sample.csv')

# %% [markdown]
# ### Get only the lead of the text in order to comply with context window and transformer model req.

# %%
# Function to get the first 200 tokens of the text, ending at a sentence boundary, considering short first sentences
nlp.add_pipe("sentencizer")
def get_lead_tokens(text):
    doc = nlp(text)
    selected_tokens = []
    token_count = 0
    sentence_count = 0
    
    sentences = list(doc.sents)
    
    if len(sentences) > 0 and len(sentences[0].text.split()) <= 15:
        selected_tokens.extend(sentences[0])
        sentence_count += 1
    
    for token in sentences[sentence_count:]:
        if token_count + len(token) <= 200:
            selected_tokens.append(token)
            token_count += len(token)
            if token_count >= 200:
                break
    
    return ' '.join([token.text for token in selected_tokens])

# Apply the function to the DataFrame with tqdm
tqdm.pandas()

df1['lead'] = df1['cleaned_text'].progress_apply(get_lead_tokens)
# Out:
# 100%|██████████| 142/142 [00:06<00:00, 22.22it/s]
# /tmp/ipykernel_2650/3756218838.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['lead'] = df1['cleaned_text'].progress_apply(get_lead_tokens)

# %%
#to make sure we don't have any half sentences at the end
#Function to drop all extra text after the very last sentence to avpid half sentences
def drop_after_last_sentence(text):
    last_period_index = text.rfind('.')
    if last_period_index != -1:
        return text[:last_period_index + 1]  # Include the period in the output
    return text

df1['lead'] = df1['lead'].apply(drop_after_last_sentence)
# Out:
# /tmp/ipykernel_2650/3597997333.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['lead'] = df1['lead'].apply(drop_after_last_sentence)

# %%
#try of it worked
df1['lead'][6023]
# Out:
# "Een aantal partijen heeft op een persconferentie gereageerd op de doorrekeningen van het CPB en de PBL. En op het feit dat CDA en VVD n et op de persconferentie waren. Vooral de progressieve partijen staan hier, zei GroenLinks-leider Klaver. Opvallend en veelzeggend dat VVD en CDA hier niet staan. Hun programma's zijn sociaal slecht en brengen economische rampspoed, stelt PvdA-Kamerlid Nijboer. Dus ik snap wel dat ze hier niet staan. D66 benadrukt dat blijkt dat Nederland sterker en groener uit de crisis komt, als hun partijprogramma wordt uitgevoerd. De crux is dus dat het wel kan, veel ambities hebben en de economie een steun in de rug geven, zei Kamerlid Van Weyenberg. D66 heeft de CO2-reductie op 60 procent staan in 2030. Dat is relatief ambitieus, maar GroenLinks gaat er nog overheen. Wij komen uit op 63 procent, zei Klaver. Dat is belangrijk, want de uitvoering blijft altijd achter, daarom heb je overshoot nodig."

# %% [markdown]
# ### Merge the title and the lead into one doc for more information

# %%
# Merge 'title' and 'first_200_words' columns with a separator ';'
df1['title_lead'] = df1['title'] + '; ' + df1['lead']
# Out:
# /tmp/ipykernel_2650/3166701124.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['title_lead'] = df1['title'] + '; ' + df1['lead']

# %%
df1['title_lead'][6023]
# Out:
# "'Opvallend en veelzeggend dat VVD en CDA hier niet staan'; Een aantal partijen heeft op een persconferentie gereageerd op de doorrekeningen van het CPB en de PBL. En op het feit dat CDA en VVD n et op de persconferentie waren. Vooral de progressieve partijen staan hier, zei GroenLinks-leider Klaver. Opvallend en veelzeggend dat VVD en CDA hier niet staan. Hun programma's zijn sociaal slecht en brengen economische rampspoed, stelt PvdA-Kamerlid Nijboer. Dus ik snap wel dat ze hier niet staan. D66 benadrukt dat blijkt dat Nederland sterker en groener uit de crisis komt, als hun partijprogramma wordt uitgevoerd. De crux is dus dat het wel kan, veel ambities hebben en de economie een steun in de rug geven, zei Kamerlid Van Weyenberg. D66 heeft de CO2-reductie op 60 procent staan in 2030. Dat is relatief ambitieus, maar GroenLinks gaat er nog overheen. Wij komen uit op 63 procent, zei Klaver. Dat is belangrijk, want de uitvoering blijft altijd achter, daarom heb je overshoot nodig."

# %% [markdown]
# ### Extract named entities from the title + lead column and save in separate columns using spacy

# %%
# Function to extract proper nouns

nlp = spacy.load('nl_core_news_sm')

def extract_proper_nouns_spacy(text):
    doc = nlp(text)
    proper_nouns = [ent.text for ent in doc.ents if ent.label_ == 'PERSON' or ent.label_ == 'ORG']
    return ', '.join(proper_nouns)
# Apply the function to the DataFrame with tqdm
tqdm.pandas()
df1['proper_nouns_text'] = df1['title_lead'].progress_apply(extract_proper_nouns_spacy)
# Out:
# 100%|██████████| 142/142 [00:02<00:00, 52.31it/s]
# /tmp/ipykernel_2650/3891323376.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['proper_nouns_text'] = df1['title_lead'].progress_apply(extract_proper_nouns_spacy)

# %%
# Calculate the number of rows for each unique date
date_counts = df1['date'].value_counts()
date_counts
# Out:
# date
# 2021-03-01 00:00:00    73
# 2021-02-28 00:00:00     7
# 2021-03-01 10:59:13     2
# 2021-03-01 10:34:06     2
# 2021-03-01 12:06:47     2
# 2021-03-01 10:30:10     2
# 2021-03-01 13:15:24     2
# 2021-03-01 14:33:22     2
# 2021-03-01 12:57:21     2
# 2021-03-01 12:59:00     2
# 2021-03-01 07:12:10     2
# 2021-03-01 07:00:58     2
# 2021-03-01 01:19:49     2
# 2021-02-27 16:40:42     1
# 2021-02-27 16:47:06     1
# 2021-02-27 17:37:33     1
# 2021-02-27 17:18:07     1
# 2021-02-27 15:20:11     1
# 2021-02-27 15:38:32     1
# 2021-02-27 15:58:15     1
# 2021-02-27 15:06:47     1
# 2021-02-28 07:53:05     1
# 2021-02-28 06:52:07     1
# 2021-02-27 22:39:37     1
# 2021-02-27 22:36:38     1
# 2021-02-27 21:15:58     1
# 2021-02-27 21:52:54     1
# 2021-02-27 20:34:14     1
# 2021-02-27 20:30:26     1
# 2021-02-27 17:37:46     1
# 2021-02-27 20:11:46     1
# 2021-02-27 18:58:44     1
# 2021-02-27 18:49:28     1
# 2021-02-28 09:25:32     1
# 2021-02-28 10:01:22     1
# 2021-02-28 13:27:28     1
# 2021-02-28 13:43:06     1
# 2021-02-28 22:43:49     1
# 2021-02-28 22:30:43     1
# 2021-02-28 22:23:54     1
# 2021-02-28 22:22:56     1
# 2021-02-28 22:15:58     1
# 2021-02-28 22:10:45     1
# 2021-02-28 22:03:24     1
# 2021-02-28 21:41:40     1
# 2021-02-28 21:37:41     1
# 2021-02-28 21:37:06     1
# 2021-02-28 18:10:52     1
# 2021-02-28 15:42:29     1
# 2021-02-28 23:10:04     1
# 2021-02-28 22:48:57     1
# 2021-02-28 23:18:22     1
# 2021-03-01 13:29:48     1
# Name: count, dtype: int64

# %% [markdown]
# ### Extract keywords from title lead using KeyBERT

# %%
from keybert import KeyBERT
from transformers.pipelines import pipeline

hf_model = pipeline('feature-extraction', model='GroNLP/bert-base-dutch-cased')
kw_model = KeyBERT(model=hf_model)
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at GroNLP/bert-base-dutch-cased and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Apply keyword extraction to each row in 'title_lead' column
def extract_keywords_from_text(text):
    keywords = kw_model.extract_keywords(str(text))
    return [keyword[0] for keyword in keywords]

df1['extracted_keywords'] = df1['title_lead'].progress_apply(extract_keywords_from_text)
# Out:
# 100%|██████████| 142/142 [02:26<00:00,  1.03s/it]
# /tmp/ipykernel_2650/3106075910.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['extracted_keywords'] = df1['title_lead'].progress_apply(extract_keywords_from_text)

# %%
#try if it worked
df1['extracted_keywords'][6023]
# Out:
# ['rampspoed', 'doorrekeningen', 'reductie', 'overshoot', 'groener']

# %%
#save to pickle
df1.to_pickle('newspaper_data/title_lead_ner_keywords_sample.pkl')

# %% [markdown]
# ### Use embedding model to get embeddings of the text
#
# We use the Dutch transformer model BERTje. On huggingface it's called `GroNLP/bert-base-dutch-cased'.

# %%
#with open('newspaper_data/title_lead_ner_keywords.pkl', 'rb') as f:
   # df= pickle.load(f)

model_name = 'GroNLP/bert-base-dutch-cased'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)

#corpus of article lead and title (the same usnit we're using throughout
article_corpus = df1['title_lead'].to_list()
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at GroNLP/bert-base-dutch-cased and are newly initialized: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
#function to get embeddings with BERTje
def get_embeddings(corpus):
    embeddings = []
    total_articles = len(corpus)

    for article in tqdm(corpus, desc='Computing embeddings', ncols=80):
        inputs = tokenizer(str(article), return_tensors='pt', padding=True, truncation=True)
        with torch.no_grad():
            outputs = model(**inputs)
        embeddings.append(outputs.pooler_output.squeeze().numpy())

    return embeddings

article_embeddings = get_embeddings(article_corpus)
# Out:
# Computing embeddings: 100%|███████████████████| 142/142 [00:05<00:00, 25.29it/s]

# %%
# Save the embeddings to a pickle file
with open('newspaper_data/title_lead_embeddings_sample.pkl', 'wb') as file:
    pickle.dump(article_embeddings, file)

# %% [markdown]
# #### Get similarities across the embeddings
#
# We do this so that we can use socine similarity to create text pairs we divide it into high matches, medium matches, and low matches and then proceed with the analysis.

# %%
import pickle
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from itertools import combinations
from tqdm import tqdm  

def load_embeddings_from_pickle(pickle_file):
    with open(pickle_file, "rb") as file:
        embeddings = pickle.load(file)
    return embeddings

def group_similar_texts(embeddings, texts, threshold_low, threshold_medium, threshold_high, df):
    similarity_matrix = cosine_similarity(embeddings)
    n_texts = len(texts)
    
    groups = {'low': [], 'medium': [], 'high': []}
    
    combination_pairs = list(combinations(range(n_texts), 2))
    for i, j in tqdm(combination_pairs, desc='Calculating Similarities'):
        similarity_score = similarity_matrix[i, j]


        if similarity_score >= threshold_high:
            groups['high'].append({
                'pair': (i, j),
                'similarity_score': similarity_score,
                'text1': texts[i],
                'text2': texts[j],
                'date1': df.iloc[i]['date'],
                'date2': df.iloc[j]['date'],
                'publisher1': df.iloc[i]['publisher'],
                'publisher2': df.iloc[j]['publisher'],
                'id1': df.iloc[i]['id'],
                'id2': df.iloc[j]['id'],
            })
        elif threshold_medium <= similarity_score < threshold_high:
            groups['medium'].append({
                'pair': (i, j),
                'similarity_score': similarity_score,
                'text1': texts[i],
                'text2': texts[j],
                'date1': df.iloc[i]['date'],
                'date2': df.iloc[j]['date'],
                'publisher1': df.iloc[i]['publisher'],
                'publisher2': df.iloc[j]['publisher'],
                'id1': df.iloc[i]['id'],
                'id2': df.iloc[j]['id'],
            })
        elif similarity_score >= threshold_low:
            groups['low'].append({
                'pair': (i, j),
                'similarity_score': similarity_score,
                'text1': texts[i],
                'text2': texts[j],
                'date1': df.iloc[i]['date'],
                'date2': df.iloc[j]['date'],
                'publisher1': df.iloc[i]['publisher'],
                'publisher2': df.iloc[j]['publisher'],
                'id1': df.iloc[i]['id'],
                'id2': df.iloc[j]['id'],
            })

    return groups

# Continue with the grouping process
threshold_low = 0.49
threshold_medium = 0.5
threshold_high = 0.7

texts = df1['title_lead'].tolist()

# Load the chunk embeddings from the pickle file
article_embeddings = load_embeddings_from_pickle('newspaper_data/title_lead_embeddings_sample.pkl')

groups = group_similar_texts(article_embeddings, texts, threshold_low, threshold_medium, threshold_high, df1)

# Process the groups and store the data in a DataFrame
data_rows = []

proper_nouns_list = df1['proper_nouns_text'].tolist()
keywords_list = df1['extracted_keywords'].tolist()

for group_name, group_data in groups.items():
    for item in tqdm(group_data, desc=f'Processing {group_name}'):
        chunk_pair = item['pair']
        similarity_score = item['similarity_score']
        text1 = item['text1']
        text2 = item['text2']
        date1 = item['date1']
        date2 = item['date2']
        publisher1 = item['publisher1']
        publisher2 = item['publisher2']
         # Add debugging statements here
        i = chunk_pair[0]
        j = chunk_pair[1]
        id1 = df1.iloc[i]['id']
        id2 = df1.iloc[j]['id']

        proper_nouns1 = proper_nouns_list[chunk_pair[0]]
        proper_nouns2 = proper_nouns_list[chunk_pair[1]]
        keywords1 = keywords_list[chunk_pair[0]]
        keywords2 = keywords_list[chunk_pair[1]]


        
        data_rows.append({
            'Similarity_Score': similarity_score,
            'Text1': text1,
            'Text2': text2,
            'Group': group_name,
            'Date1': date1,
            'Date2': date2,
            'Publisher1': publisher1,
            'Publisher2': publisher2,
            'ID1': id1,
            'ID2': id2,
            'proper_nouns1': proper_nouns1,
            'proper_nouns2': proper_nouns2,
            'keywords1': keywords1,
            'keywords2': keywords2
        })

# Create a DataFrame from the processed data
df2 = pd.DataFrame(data_rows)

# Set maximum column width for display
pd.set_option('display.max_colwidth', 100)
# Out:
# Calculating Similarities: 100%|██████████| 10011/10011 [00:03<00:00, 2751.93it/s]
# Processing low: 0it [00:00, ?it/s]
# Processing medium: 100%|██████████| 1290/1290 [00:00<00:00, 7824.72it/s]
# Processing high: 100%|██████████| 8721/8721 [00:01<00:00, 8168.98it/s]

# %%
length = len(df2)
result = f"The length of dataframe with all possible matching pairs is {length}."
print(result)
# Out:
# The length of dataframe with all possible matching pairs is 10011.

# %%
df2
# Out:
#        Similarity_Score  \
# 0              0.599136
# 1              0.696328
# 2              0.667074
# 3              0.602991
# 4              0.666908
# ...                 ...
# 10006          0.871495
# 10007          0.871495
# 10008          0.762449
# 10009          0.762449
# 10010          1.000000
#
#                                                                                                      Text1  \
# 0      De uitzending van 27 februari: Verkiezingsspecial: in gesprek met Thierry Baudet / Corona-uitbra...
# 1      De uitzending van 27 februari: Verkiezingsspecial: in gesprek met Thierry Baudet / Corona-uitbra...
# 2      De uitzending van 27 februari: Verkiezingsspecial: in gesprek met Thierry Baudet / Corona-uitbra...
# 3      De uitzending van 27 februari: Verkiezingsspecial: in gesprek met Thierry Baudet / Corona-uitbra...
# 4      De uitzending van 27 februari: Verkiezingsspecial: in gesprek met Thierry Baudet / Corona-uitbra...
# ...                                                                                                    ...
# 10006  'Opvallend en veelzeggend dat VVD en CDA hier niet staan'; Een aantal partijen heeft op een pers...
# 10007  'Opvallend en veelzeggend dat VVD en CDA hier niet staan'; Een aantal partijen heeft op een pers...
# 10008  Podcast De Stemming: Verkiezingscampagne maakt nog weinig los bij kiezer; VVD-lijsttrekker Mark ...
# 10009  Podcast De Stemming: Verkiezingscampagne maakt nog weinig los bij kiezer; VVD-lijsttrekker Mark ...
# 10010  De Jonge: lijsttrekkers moeten in campagne behoedzaam zijn over corona; Minister de Jonge van Vo...
#
#                                                                                                      Text2  \
# 0      Ziekenhuisbezetting daalt met 55; De bezetting in de ziekenhuizen is de afgelopen dag afgenomen ...
# 1      D66 pleit voor vaccinatiebewijs; D66-lijsttrekker Sigrid Kaag wil mensen die gevaccineerd zijn m...
# 2      Veel woede over schip met 1.800 koeien dat al twee maanden op zee dobbert; De woede van dierenre...
# 3      Vondelpark opnieuw dicht; Het Vondelpark is vanwege te grote drukte opnieuw gesloten . Dat meldt...
# 4      Ook Texel begonnen met vaccineren; Als laatste Waddeneiland is ook Texel begonnen met vaccineren...
# ...                                                                                                    ...
# 10006  De Jonge: lijsttrekkers moeten in campagne behoedzaam zijn over corona; Minister de Jonge van Vo...
# 10007  De Jonge: lijsttrekkers moeten in campagne behoedzaam zijn over corona ; Minister de Jonge van V...
# 10008  De Jonge: lijsttrekkers moeten in campagne behoedzaam zijn over corona; Minister de Jonge van Vo...
# 10009  De Jonge: lijsttrekkers moeten in campagne behoedzaam zijn over corona ; Minister de Jonge van V...
# 10010  De Jonge: lijsttrekkers moeten in campagne behoedzaam zijn over corona ; Minister de Jonge van V...
#
#         Group               Date1               Date2    Publisher1  \
# 0      medium 2021-02-27 15:06:47 2021-02-27 15:20:11     Nieuwsuur
# 1      medium 2021-02-27 15:06:47 2021-02-27 16:40:42     Nieuwsuur
# 2      medium 2021-02-27 15:06:47 2021-02-27 16:47:06     Nieuwsuur
# 3      medium 2021-02-27 15:06:47 2021-02-27 17:18:07     Nieuwsuur
# 4      medium 2021-02-27 15:06:47 2021-02-27 17:37:33     Nieuwsuur
# ...       ...                 ...                 ...           ...
# 10006    high 2021-03-01 13:15:24 2021-03-01 14:33:22  NOS liveblog
# 10007    high 2021-03-01 13:15:24 2021-03-01 14:33:22  NOS liveblog
# 10008    high 2021-03-01 13:29:48 2021-03-01 14:33:22    NOS nieuws
# 10009    high 2021-03-01 13:29:48 2021-03-01 14:33:22    NOS nieuws
# 10010    high 2021-03-01 14:33:22 2021-03-01 14:33:22  NOS liveblog
#
#          Publisher2      ID1      ID2  \
# 0      NOS liveblog  3287580  3287538
# 1      NOS liveblog  3287580  3287535
# 2             NU.nl  3287580  3288534
# 3      NOS liveblog  3287580  3287534
# 4      NOS liveblog  3287580  3287533
# ...             ...      ...      ...
# 10006  NOS liveblog  3287398  6290505
# 10007  NOS liveblog  3287398  3287397
# 10008  NOS liveblog  6290581  6290505
# 10009  NOS liveblog  6290581  3287397
# 10010  NOS liveblog  6290505  3287397
#
#                                                                                              proper_nouns1  \
# 0           Thierry Baudet, Thierry, Forum voor Democratie, Provinciale Statenverkiezingen, Thierry Baudet
# 1           Thierry Baudet, Thierry, Forum voor Democratie, Provinciale Statenverkiezingen, Thierry Baudet
# 2           Thierry Baudet, Thierry, Forum voor Democratie, Provinciale Statenverkiezingen, Thierry Baudet
# 3           Thierry Baudet, Thierry, Forum voor Democratie, Provinciale Statenverkiezingen, Thierry Baudet
# 4           Thierry Baudet, Thierry, Forum voor Democratie, Provinciale Statenverkiezingen, Thierry Baudet
# ...                                                                                                    ...
# 10006                               CDA, CPB, PBL, CDA, CDA, Kamerlid Van Weyenberg, ambitieus, GroenLinks
# 10007                               CDA, CPB, PBL, CDA, CDA, Kamerlid Van Weyenberg, ambitieus, GroenLinks
# 10008  Verkiezingscampagne, Mark Rutte, Joost Vullings, Van der Wulp, CDA, Gijs Rademaker, GroenLinks, ...
# 10009  Verkiezingscampagne, Mark Rutte, Joost Vullings, Van der Wulp, CDA, Gijs Rademaker, GroenLinks, ...
# 10010                                                                            Jonge van Volksgezondheid
#
#                                              proper_nouns2  \
# 0                                                 IC, RIVM
# 1                              D66, Sigrid Kaag, Isra, Wel
# 2      ElBeik, Libi, Republiek Cyprus, ElBeik, Karim Allah
# 3
# 4                                                       NH
# ...                                                    ...
# 10006                            Jonge van Volksgezondheid
# 10007                            Jonge van Volksgezondheid
# 10008                            Jonge van Volksgezondheid
# 10009                            Jonge van Volksgezondheid
# 10010                            Jonge van Volksgezondheid
#
#                                                                            keywords1  \
# 0                  [amsterdamse, schoolleiders, baudet, thierry, verkiezingsspecial]
# 1                  [amsterdamse, schoolleiders, baudet, thierry, verkiezingsspecial]
# 2                  [amsterdamse, schoolleiders, baudet, thierry, verkiezingsspecial]
# 3                  [amsterdamse, schoolleiders, baudet, thierry, verkiezingsspecial]
# 4                  [amsterdamse, schoolleiders, baudet, thierry, verkiezingsspecial]
# ...                                                                              ...
# 10006                      [rampspoed, doorrekeningen, reductie, overshoot, groener]
# 10007                      [rampspoed, doorrekeningen, reductie, overshoot, groener]
# 10008  [onderhandelingsmanoeuvre, verkiezingsdebatten, desondanks, rtl, opiniepanel]
# 10009  [onderhandelingsmanoeuvre, verkiezingsdebatten, desondanks, rtl, opiniepanel]
# 10010                       [besmettingscijfers, rtl, holland, versoepelingen, pati]
#
#                                                                                     keywords2
# 0                                  [4605, besmettingen, ziekenhuisbezetting, coronapati, 525]
# 1      [gevaccineerd, gevaccineerde, vaccinatiepaspoort, vaccinatiebewijs, coronatestuitslag]
# 2                      [blauwtongvirus, dierenrechtenorganisaties, turkije, famagusta, karim]
# 3                                          [meldt, vondelpark, amsterdam, tilburg, toestroom]
# 4                      [gevaccineerd, vaccineren, waddeneiland, gehandicaptenzorg, texelaars]
# ...                                                                                       ...
# 10006                                [besmettingscijfers, rtl, holland, versoepelingen, pati]
# 10007                                [besmettingscijfers, rtl, holland, versoepelingen, pati]
# 10008                                [besmettingscijfers, rtl, holland, versoepelingen, pati]
# 10009                                [besmettingscijfers, rtl, holland, versoepelingen, pati]
# 10010                                [besmettingscijfers, rtl, holland, versoepelingen, pati]
#
# [10011 rows x 14 columns]

# %%
df2.sort_values(by = 'Similarity_Score', ascending = False)
# Out:
#        Similarity_Score  \
# 9956           1.000000
# 9875           1.000000
# 9975           1.000000
# 9801           1.000000
# 10001          1.000000
# ...                 ...
# 410            0.544579
# 440            0.538848
# 392            0.535320
# 9              0.523266
# 481            0.502483
#
#                                                                                                      Text1  \
# 9956   De uitzending van 1 maart: Gasvrij duurder dan verwacht / IC's vol in Hoorn / Genomineerden Libr...
# 9875   Partijen willen hogere lasten voor bedrijven, blijkt uit doorrekeningen CPB; Tien partijen kieze...
# 9975   Milieuclubs niet echt blij met doorrekeningen; Milieuorganisaties zijn teleurgesteld over de ver...
# 9801   Wekdienst 1/3: Verkiezingsprogramma's doorgerekend • Mbo-studenten naar school; Goedemorgen ! De...
# 10001  'Opvallend en veelzeggend dat VVD en CDA hier niet staan'; Een aantal partijen heeft op een pers...
# ...                                                                                                    ...
# 410    Dode en gewonde door zuurstofexplosie corona-afdeling Oekraïne; In een ziekenhuis in Tsjernivtsi...
# 440    Dode en gewonde door zuurstofexplosie corona-afdeling Oekraïne; In een ziekenhuis in Tsjernivtsi...
# 392    Park Breda en terras in Gelderse Laren ontruimd; Aan het begin van de avond is park Valkenberg i...
# 9      De uitzending van 27 februari: Verkiezingsspecial: in gesprek met Thierry Baudet / Corona-uitbra...
# 481    Dode en gewonde door zuurstofexplosie corona-afdeling Oekraïne; In een ziekenhuis in Tsjernivtsi...
#
#                                                                                                      Text2  \
# 9956   De uitzending van 1 maart: Gasvrij duurder dan verwacht / IC's vol in Hoorn / Genomineerden Libr...
# 9875   Partijen willen hogere lasten voor bedrijven, blijkt uit doorrekeningen CPB; Tien partijen kieze...
# 9975   Milieuclubs niet echt blij met doorrekeningen; Milieuorganisaties zijn teleurgesteld over de ver...
# 9801   Wekdienst 1/3: Verkiezingsprogramma's doorgerekend • Mbo-studenten naar school; Goedemorgen ! De...
# 10001  'Opvallend en veelzeggend dat VVD en CDA hier niet staan'; Een aantal partijen heeft op een pers...
# ...                                                                                                    ...
# 410    Laatste coronanieuws: 4729 nieuwe besmettingen, hoger dan weekgemiddelde; 18.50 uur | Aantal nie...
# 440    Vaccinatie-paspoort; Commentaar Hans van zon Beetje bij beetje maken politici de geesten rijp vo...
# 392    Jozef Deleu: ‘Iets onder woorden brengen gaat sneller in een gedicht’; Wat maakt het leven de mo...
# 9      Dode en gewonde door zuurstofexplosie corona-afdeling Oekraïne; In een ziekenhuis in Tsjernivtsi...
# 481    Jozef Deleu: ‘Iets onder woorden brengen gaat sneller in een gedicht’; Wat maakt het leven de mo...
#
#         Group               Date1               Date2    Publisher1  \
# 9956     high 2021-03-01 12:06:47 2021-03-01 12:06:47     Nieuwsuur
# 9875     high 2021-03-01 10:30:10 2021-03-01 10:30:10    NOS nieuws
# 9975     high 2021-03-01 12:57:21 2021-03-01 12:57:21  NOS liveblog
# 9801     high 2021-03-01 07:00:58 2021-03-01 07:00:58    NOS nieuws
# 10001    high 2021-03-01 13:15:24 2021-03-01 13:15:24  NOS liveblog
# ...       ...                 ...                 ...           ...
# 410    medium 2021-02-27 22:39:37 2021-02-28 00:00:00  NOS liveblog
# 440    medium 2021-02-27 22:39:37 2021-03-01 00:00:00  NOS liveblog
# 392    medium 2021-02-27 21:15:58 2021-03-01 00:00:00  NOS liveblog
# 9      medium 2021-02-27 15:06:47 2021-02-27 22:39:37     Nieuwsuur
# 481    medium 2021-02-27 22:39:37 2021-03-01 00:00:00  NOS liveblog
#
#                     Publisher2      ID1      ID2  \
# 9956                 Nieuwsuur  3287485  6290579
# 9875                NOS nieuws  3287448  6290557
# 9975              NOS liveblog  6290507  3287399
# 9801                NOS nieuws  6290568  3287459
# 10001             NOS liveblog  6290506  3287398
# ...                        ...      ...      ...
# 410    Het Financieele Dagblad  3287529  3290679
# 440           Algemeen Dagblad  3287529  3286195
# 392            NRC Handelsblad  3287530  3285657
# 9                 NOS liveblog  3287580  3287529
# 481            NRC Handelsblad  3287529  3285657
#
#                                                                                              proper_nouns1  \
# 9956                                                   Friese Garijp, Noord-Holland Noord, Jan Nieuwenburg
# 9875   CPB, SGP, CPB, VVD, CDA, D66, GroenLinks, SP, PvdA, ChristenUnie, SGP, PVV, Partij voor de Diere...
# 9975   Milieuclubs, Kamers, CDA, GroenLinks, D66, PvdA, Greenpeace, D66, GroenLinks, PvdA, ChristenUnie...
# 9801                                                                                    Planbureau, Baudet
# 10001                               CDA, CPB, PBL, CDA, CDA, Kamerlid Van Weyenberg, ambitieus, GroenLinks
# ...                                                                                                    ...
# 410                                                                                  Oekra, Twintig, Oekra
# 440                                                                                  Oekra, Twintig, Oekra
# 392                                                                                             Park Breda
# 9           Thierry Baudet, Thierry, Forum voor Democratie, Provinciale Statenverkiezingen, Thierry Baudet
# 481                                                                                  Oekra, Twintig, Oekra
#
#                                                                                              proper_nouns2  \
# 9956                                                   Friese Garijp, Noord-Holland Noord, Jan Nieuwenburg
# 9875   CPB, SGP, CPB, VVD, CDA, D66, GroenLinks, SP, PvdA, ChristenUnie, SGP, PVV, Partij voor de Diere...
# 9975   Milieuclubs, Kamers, CDA, GroenLinks, D66, PvdA, Greenpeace, D66, GroenLinks, PvdA, ChristenUnie...
# 9801                                                                                    Planbureau, Baudet
# 10001                               CDA, CPB, PBL, CDA, CDA, Kamerlid Van Weyenberg, ambitieus, GroenLinks
# ...                                                                                                    ...
# 410                                                        RIVM, RIVM, Pati, RIVM, RIVM, RIVM mede bepaald
# 440                   Commentaar, Hans van zon Beetje, Angela Merkel, Mark Rutte, D66, Sigrid Kaag, Isra l
# 392                                Jozef Deleu, Jozef Deleu, Nederland zelfzuchtiger, Jozef Deleu, Lyrisch
# 9                                                                                    Oekra, Twintig, Oekra
# 481                                Jozef Deleu, Jozef Deleu, Nederland zelfzuchtiger, Jozef Deleu, Lyrisch
#
#                                                                                  keywords1  \
# 9956                     [nieuwenburg, gasvrij, besmettingen, aardgasvrij, versoepelingen]
# 9875   [lastenverzwaring, doorrekeningen, verkiezingsprogramma, overheidsuitgaven, 50plus]
# 9975               [greenpeace, nagestreefde, doorrekeningen, milieuclubs, klimaatakkoord]
# 9801          [wolkenvelden, klimaatdoelen, vriespunt, verkiezingsprogramma, leefomgeving]
# 10001                            [rampspoed, doorrekeningen, reductie, overshoot, groener]
# ...                                                                                    ...
# 410                  [tsjernivtsi, zaporizja, zuurstofexplosie, oekraïne, zuurstofleiding]
# 440                  [tsjernivtsi, zaporizja, zuurstofexplosie, oekraïne, zuurstofleiding]
# 392                             [nageleefd, vondelpark, amsterdamse, gelderland, kaarsjes]
# 9                        [amsterdamse, schoolleiders, baudet, thierry, verkiezingsspecial]
# 481                  [tsjernivtsi, zaporizja, zuurstofexplosie, oekraïne, zuurstofleiding]
#
#                                                                                  keywords2
# 9956                     [nieuwenburg, gasvrij, besmettingen, aardgasvrij, versoepelingen]
# 9875   [lastenverzwaring, doorrekeningen, verkiezingsprogramma, overheidsuitgaven, 50plus]
# 9975               [greenpeace, nagestreefde, doorrekeningen, milieuclubs, klimaatakkoord]
# 9801          [wolkenvelden, klimaatdoelen, vriespunt, verkiezingsprogramma, leefomgeving]
# 10001                            [rampspoed, doorrekeningen, reductie, overshoot, groener]
# ...                                                                                    ...
# 410                      [meldt, 4605, coronabesmettingen, besmettingen, coronabesmetting]
# 440                        [vaccinatiepaspoort, gevaccineerde, herwonnen, europese, rutte]
# 392                                        [vlaams, zelfzuchtiger, bejaard, rekkem, jozef]
# 9                    [tsjernivtsi, zaporizja, zuurstofexplosie, oekraïne, zuurstofleiding]
# 481                                        [vlaams, zelfzuchtiger, bejaard, rekkem, jozef]
#
# [10011 rows x 14 columns]

# %%
# Filter out rows where ID1 and ID2 are the same
#df_filtered = df2[df2['ID1'] != df2['ID2']]

# %%
#df_filtered

# %%
def identical_matches(df):
    identical_matches = df[df['Similarity_Score'] > 0.999]
    return identical_matches
    #return len(identical_matches)

# Use the function to count identical matches
identical_matches = identical_matches(df2)
len(identical_matches)

# Remove identical matches from df2
df2 = df2[df2['Similarity_Score'] <= 0.999]

df2.sort_values(by = 'Similarity_Score', ascending = True)
# Out:
#        Similarity_Score  \
# 481            0.502483
# 9              0.523266
# 392            0.535320
# 440            0.538848
# 410            0.544579
# ...                 ...
# 3389           0.948800
# 9999           0.995982
# 9994           0.995982
# 9995           0.995982
# 10000          0.995982
#
#                                                                                                      Text1  \
# 481    Dode en gewonde door zuurstofexplosie corona-afdeling Oekraïne; In een ziekenhuis in Tsjernivtsi...
# 9      De uitzending van 27 februari: Verkiezingsspecial: in gesprek met Thierry Baudet / Corona-uitbra...
# 392    Park Breda en terras in Gelderse Laren ontruimd; Aan het begin van de avond is park Valkenberg i...
# 440    Dode en gewonde door zuurstofexplosie corona-afdeling Oekraïne; In een ziekenhuis in Tsjernivtsi...
# 410    Dode en gewonde door zuurstofexplosie corona-afdeling Oekraïne; In een ziekenhuis in Tsjernivtsi...
# ...                                                                                                    ...
# 3389   Hoogste bestuursrechter liet forse steken vallen in affaire kinderopvangtoeslagen; De affaire ro...
# 9999   De Jonge: lijsttrekkers moeten in campagne behoedzaam zijn over corona ; Minister De Jonge van V...
# 9994   De Jonge: lijsttrekkers moeten in campagne behoedzaam zijn over corona; Minister De Jonge van Vo...
# 9995   De Jonge: lijsttrekkers moeten in campagne behoedzaam zijn over corona; Minister De Jonge van Vo...
# 10000  De Jonge: lijsttrekkers moeten in campagne behoedzaam zijn over corona ; Minister De Jonge van V...
#
#                                                                                                      Text2  \
# 481    Jozef Deleu: ‘Iets onder woorden brengen gaat sneller in een gedicht’; Wat maakt het leven de mo...
# 9      Dode en gewonde door zuurstofexplosie corona-afdeling Oekraïne; In een ziekenhuis in Tsjernivtsi...
# 392    Jozef Deleu: ‘Iets onder woorden brengen gaat sneller in een gedicht’; Wat maakt het leven de mo...
# 440    Vaccinatie-paspoort; Commentaar Hans van zon Beetje bij beetje maken politici de geesten rijp vo...
# 410    Laatste coronanieuws: 4729 nieuwe besmettingen, hoger dan weekgemiddelde; 18.50 uur | Aantal nie...
# ...                                                                                                    ...
# 3389   Hoogste bestuursrechter liet forse steken vallen in toeslagenaffaire; Pia Lokin-Sassen CDA De af...
# 9999   De Jonge: lijsttrekkers moeten in campagne behoedzaam zijn over corona; Minister de Jonge van Vo...
# 9994   De Jonge: lijsttrekkers moeten in campagne behoedzaam zijn over corona; Minister de Jonge van Vo...
# 9995   De Jonge: lijsttrekkers moeten in campagne behoedzaam zijn over corona ; Minister de Jonge van V...
# 10000  De Jonge: lijsttrekkers moeten in campagne behoedzaam zijn over corona ; Minister de Jonge van V...
#
#         Group               Date1               Date2  \
# 481    medium 2021-02-27 22:39:37 2021-03-01 00:00:00
# 9      medium 2021-02-27 15:06:47 2021-02-27 22:39:37
# 392    medium 2021-02-27 21:15:58 2021-03-01 00:00:00
# 440    medium 2021-02-27 22:39:37 2021-03-01 00:00:00
# 410    medium 2021-02-27 22:39:37 2021-02-28 00:00:00
# ...       ...                 ...                 ...
# 3389     high 2021-02-28 00:00:00 2021-03-01 00:00:00
# 9999     high 2021-03-01 12:59:00 2021-03-01 14:33:22
# 9994     high 2021-03-01 12:59:00 2021-03-01 14:33:22
# 9995     high 2021-03-01 12:59:00 2021-03-01 14:33:22
# 10000    high 2021-03-01 12:59:00 2021-03-01 14:33:22
#
#                     Publisher1               Publisher2      ID1      ID2  \
# 481               NOS liveblog          NRC Handelsblad  3287529  3285657
# 9                    Nieuwsuur             NOS liveblog  3287580  3287529
# 392               NOS liveblog          NRC Handelsblad  3287530  3285657
# 440               NOS liveblog         Algemeen Dagblad  3287529  3286195
# 410               NOS liveblog  Het Financieele Dagblad  3287529  3290679
# ...                        ...                      ...      ...      ...
# 3389   Het Financieele Dagblad  Het Financieele Dagblad  3290695  3290608
# 9999              NOS liveblog             NOS liveblog  3287414  6290505
# 9994              NOS liveblog             NOS liveblog  6290523  6290505
# 9995              NOS liveblog             NOS liveblog  6290523  3287397
# 10000             NOS liveblog             NOS liveblog  3287414  3287397
#
#                                                                                              proper_nouns1  \
# 481                                                                                  Oekra, Twintig, Oekra
# 9           Thierry Baudet, Thierry, Forum voor Democratie, Provinciale Statenverkiezingen, Thierry Baudet
# 392                                                                                             Park Breda
# 440                                                                                  Oekra, Twintig, Oekra
# 410                                                                                  Oekra, Twintig, Oekra
# ...                                                                                                    ...
# 3389   Andr Bosman, VVD, Tweede Kamer, Raad van State, Bart Jan van Ettekoven, Herman Tjeenk Willink, R...
# 9999                                                                             Jonge van Volksgezondheid
# 9994                                                                             Jonge van Volksgezondheid
# 9995                                                                             Jonge van Volksgezondheid
# 10000                                                                            Jonge van Volksgezondheid
#
#                                                                                              proper_nouns2  \
# 481                                Jozef Deleu, Jozef Deleu, Nederland zelfzuchtiger, Jozef Deleu, Lyrisch
# 9                                                                                    Oekra, Twintig, Oekra
# 392                                Jozef Deleu, Jozef Deleu, Nederland zelfzuchtiger, Jozef Deleu, Lyrisch
# 440                   Commentaar, Hans van zon Beetje, Angela Merkel, Mark Rutte, D66, Sigrid Kaag, Isra l
# 410                                                        RIVM, RIVM, Pati, RIVM, RIVM, RIVM mede bepaald
# ...                                                                                                    ...
# 3389   Lokin-Sassen CDA, Andr Bosman, VVD, Tweede Kamer, Raad van State, Bart Jan van Ettekoven, Herman...
# 9999                                                                             Jonge van Volksgezondheid
# 9994                                                                             Jonge van Volksgezondheid
# 9995                                                                             Jonge van Volksgezondheid
# 10000                                                                            Jonge van Volksgezondheid
#
#                                                                                 keywords1  \
# 481                 [tsjernivtsi, zaporizja, zuurstofexplosie, oekraïne, zuurstofleiding]
# 9                       [amsterdamse, schoolleiders, baudet, thierry, verkiezingsspecial]
# 392                            [nageleefd, vondelpark, amsterdamse, gelderland, kaarsjes]
# 440                 [tsjernivtsi, zaporizja, zuurstofexplosie, oekraïne, zuurstofleiding]
# 410                 [tsjernivtsi, zaporizja, zuurstofexplosie, oekraïne, zuurstofleiding]
# ...                                                                                   ...
# 3389   [overheidsinstantie, kinderopvangtoeslagen, ettekoven, dwingendrechtelijk, tjeenk]
# 9999                             [besmettingscijfers, rtl, holland, versoepelingen, pati]
# 9994                             [besmettingscijfers, rtl, holland, versoepelingen, pati]
# 9995                             [besmettingscijfers, rtl, holland, versoepelingen, pati]
# 10000                            [besmettingscijfers, rtl, holland, versoepelingen, pati]
#
#                                                                           keywords2
# 481                                 [vlaams, zelfzuchtiger, bejaard, rekkem, jozef]
# 9             [tsjernivtsi, zaporizja, zuurstofexplosie, oekraïne, zuurstofleiding]
# 392                                 [vlaams, zelfzuchtiger, bejaard, rekkem, jozef]
# 440                 [vaccinatiepaspoort, gevaccineerde, herwonnen, europese, rutte]
# 410               [meldt, 4605, coronabesmettingen, besmettingen, coronabesmetting]
# ...                                                                             ...
# 3389   [overheidsinstantie, kinderopvangtoeslagen, ettekoven, medewetgever, tjeenk]
# 9999                       [besmettingscijfers, rtl, holland, versoepelingen, pati]
# 9994                       [besmettingscijfers, rtl, holland, versoepelingen, pati]
# 9995                       [besmettingscijfers, rtl, holland, versoepelingen, pati]
# 10000                      [besmettingscijfers, rtl, holland, versoepelingen, pati]
#
# [9996 rows x 14 columns]

# %% [markdown]
# #### Save final dataframe with text pairs for LLM's
#
# We save the full dataframe, only highly matching pairs (>.70) as well as a sample of 100 from the highly matching pairs for validation validation purposes.

# %%
#save full output to a pickle file
df2.to_pickle('newspaper_data/title_lead_similarity_sample.pkl')

# %%
# Calculate the sample size as 1% of the total number of rows
sample_size_percent = 1
total_rows = len(df2)
sample_size = int((sample_size_percent / 100) * total_rows)

# Generate a random sample of size sample_size
sample = df2.sample(n=sample_size, random_state=42)  # Use a fixed random_state for reproducibility

# Save the sample as CSV for manual coding
sample.to_csv('newspaper_data/sample_1percent.csv', index=False)

sample.to_excel('newspaper_data/sample_1percent.xlsx', index=True)

# Save the updated DataFrame (excluding the sampled rows) as an Excel file to avoid formatting issues
remaining_data = df2.drop(sample.index)
remaining_data.to_excel("newspaper_data/remaining_data.xlsx", index=False)

# Save the updated DataFrame (excluding the sampled rows) as a CSV file
remaining_data.to_csv("newspaper_data/remaining_data.csv", index=False)

# %%
sample
# Out:
#       Similarity_Score  \
# 1078          0.684651
# 4337          0.876639
# 8967          0.803055
# 5457          0.858289
# 2407          0.779277
# ...                ...
# 8277          0.849066
# 8317          0.777635
# 3251          0.772102
# 6224          0.866637
# 7534          0.833621
#
#                                                                                                     Text1  \
# 1078  De laatste, over integriteit; Hilde Sennema Ze stuurde een foto van haar tuin vol krokussen, bli...
# 4337  Verkiezingsdebat: Jetten zegt niet op wie hij stemt; D66-fractieleider Rob Jetten gaat stemmen o...
# 8967  Kaag: vaccinatiebewijs of negatieve test moet weer toegang bieden tot 'het leven'; E r moet een ...
# 5457  Rutte tegen Klaver: U bent aan het overtoepen! Klaver: 'Er wordt hier gelogen'; VVD-leider Rutte...
# 2407  Oud-vluchtelingen popelen om het parlement in te gaan; Op de kandidatenlijsten voor de Tweede Ka...
# ...                                                                                                   ...
# 8277  Contact met de kiezer; Geen flyerende lijsttrekkers in windjacks op markten deze keer . Kandidaa...
# 8317  Een sterkere EU graag, maar nu is dat even bijzaak; verkiezingen 2021 de campagne Het klimaat, d...
# 3251  Makers van vaccins redden de mens, niet de belegger; Wie farmaceut zegt , zegt overwinsten altha...
# 6224  Opstand begin van corona-uitbraak; Opstand begin van corona-uitbraak In de gevangenis van Ter Ap...
# 7534  Economen: hogere belastingen jagen bedrijven weg; De plannen van politieke partijen om de lasten...
#
#                                                                                                     Text2  \
# 1078  Baudet: corona niet bewust wereld in geslingerd; Het coronavirus is niet bewust de wereld in ges...
# 4337  Einde nadert langzaam voor omstreden investeringssubsidie Bik; Multinationals Het CDA wil zo sne...
# 8967  De uitzending van 1 maart: Gasvrij duurder dan verwacht / IC's vol in Hoorn / Genomineerden Libr...
# 5457  Stelling 5: gevaccineerde burgers moeten als eersten hun vrijheid terugkrijgen; D66-lijsttrekker...
# 2407  Lezersreacties; Vertaling Als schrijfster kan Marieke Lucas Rijneveld zich als geen ander inleve...
# ...                                                                                                   ...
# 8277  Europese Volt rekent op een  zetel in Den Haag; Tweede Kamerverkiezingen Voor het eerst doet een...
# 8317  En toch is Rutte erbij in verkiezingsdebat van de nummers twee; aanloop 17 maart Niet de lijsttr...
# 3251  Een vraag van een slachtoffer van de toeslagenaffaire aan VVD-lijsttrekker en demissionair premi...
# 6224  Europese Volt rekent op een  zetel in Den Haag; Tweede Kamerverkiezingen Voor het eerst doet een...
# 7534  Meeste partijen willen hoger minimumloon, maar leggen rekening verschillend neer; Bijna alle par...
#
#        Group               Date1               Date2               Publisher1  \
# 1078  medium 2021-03-01 00:00:00 2021-03-01 10:34:06  Het Financieele Dagblad
# 4337    high 2021-02-28 13:27:28 2021-03-01 00:00:00               NOS nieuws
# 8967    high 2021-03-01 00:00:00 2021-03-01 12:06:47            De Volkskrant
# 5457    high 2021-02-28 22:30:43 2021-02-28 23:18:22             NOS liveblog
# 2407    high 2021-02-27 18:49:28 2021-03-01 00:00:00               NOS nieuws
# ...      ...                 ...                 ...                      ...
# 8277    high 2021-03-01 00:00:00 2021-03-01 00:00:00                    Trouw
# 8317    high 2021-03-01 00:00:00 2021-03-01 00:00:00                    Trouw
# 3251    high 2021-02-28 00:00:00 2021-02-28 22:15:58  Het Financieele Dagblad
# 6224    high 2021-03-01 00:00:00 2021-03-01 00:00:00             De Telegraaf
# 7534    high 2021-03-01 00:00:00 2021-03-01 00:00:00  Het Financieele Dagblad
#
#                    Publisher2      ID1      ID2  \
# 1078               NOS nieuws  3290640  3287447
# 4337                    Trouw  3287516  3285323
# 8967                Nieuwsuur  3285227  6290579
# 5457             NOS liveblog  3287472  3287467
# 2407                    Trouw  3287550  3285370
# ...                       ...      ...      ...
# 8277          NRC Handelsblad  3285326  3285633
# 8317            De Volkskrant  3285325  3285230
# 3251             NOS liveblog  3290697  3287475
# 6224          NRC Handelsblad  3286378  3285633
# 7534  Het Financieele Dagblad  3290606  3290622
#
#                                                                                             proper_nouns1  \
# 1078                                                                                                  God
# 4337  WNL, Rick Nieman, Sigrid Kaag, Nieman, Brinkman, CDA, WNL, VVD, Van Ark, PVV, Agema, CDA Pieter ...
# 8967                                                       E r, Sigrid Kaag, stadions, D66, Kaag zaterdag
# 5457                                                                      Planbureau voor de Leefomgeving
# 2407              Tweede Kamer, Ellian, VVD, Ellian, advocaat van beroep, Afghanistan, Afshin Ellian, VVD
# ...                                                                                                   ...
# 8277                             Gert-Jan Segers, Mark Rutte, Forum voor Democratie, Hubert Bruls, Baudet
# 8317                                                                                        PVV, D66, VVD
# 3251  Makers van vaccins redden de mens, Martin Shkreli, GroenLinks, GroenLinks, GroenLinks, Europees ...
# 6224  Opstand, Ter Apel, FNV, Sander Dekker, PI, Ter Apel, Koen Nederlof TER, APEL, Ter Apel, Telegraa...
# 7534                                    Economen, Jakob de Haan, VVD, Centraal Planbureau voorlegden, VVD
#
#                                                                                             proper_nouns2  \
# 1078  Baudet, Forum voor Democratie-voorman Thierry Baudet, NOS, Radio 1 Journaal, FvD-kiezers, Baudet...
# 4337                                      CDA, Pieter, CDA, euro, WNL, Centraal Planbureau CPB, VVD, euro
# 8967                                                  Friese Garijp, Noord-Holland Noord, Jan Nieuwenburg
# 5457                                             Wilders, Marijnissen, Marijnissen, Klaver van GroenLinks
# 2407                           Lucas Rijneveld, Scheffer Tytsjerk Smet, Frank Hendriks, Sigrid Kaag Trouw
# ...                                                                                                   ...
# 8277  Europese Volt, Volt, Jan Boekestijn, Sander Schimmelpenninck, Volt, Volt, Geert Mak, Tweede Kame...
# 8317  WNL, CDA'er Pieter Omtzigt, Tamara van Ark, Jerry Seinfeld, Desondanks, VVD, PVV, CDA, D66, PvdA...
# 3251                                                                     Kristie, Jullie, Kristie, Jullie
# 6224  Europese Volt, Volt, Jan Boekestijn, Sander Schimmelpenninck, Volt, Volt, Geert Mak, Tweede Kame...
# 7534                                                VVD, CDA, D66, ChristenUnie, CDA, SP, VVD, GroenLinks
#
#                                                                          keywords1  \
# 1078                      [sennema, hilde, humanistische, wennen, televisiekijken]
# 4337                [leiderschapscrisis, omtzigt, verkiezingsdebat, lubbers, ruud]
# 8967  [gevaccineerd, gevaccineerden, gevaccineerde, vaccinatiebewijs, coronatests]
# 5457            [klimaatdoelen, verkleint, klimaatwensen, leefomgeving, amsterdam]
# 2407          [afghanistan, rechtsgeleerde, verantwoordelijkheid, popelen, ellian]
# ...                                                                            ...
# 8277              [livesessies, vrijheidskaravaan, flyerende, facebook, windjacks]
# 8317            [bikkelharde, mondkapjes, europese, oprapen, beschermingsmiddelen]
# 3251  [farmaceut, dwanglicenties, pharmaceuticals, vaccinfabrikanten, gedetineerd]
# 6224                                     [indigd, coronavirus, sander, bajes, anp]
# 7534             [verslechtert, vestigingsklimaat, verkiezingsplannen, mrd, jakob]
#
#                                                                                  keywords2
# 1078                             [virussen, chinees, ebolavirus, ingestonken, coronavirus]
# 4337        [doorrekeningen, bevriezing, dividendbelasting, verkiezingsprogramma, omtzigt]
# 8967                     [nieuwenburg, gasvrij, besmettingen, aardgasvrij, versoepelingen]
# 5457                    [sneltesten, gevaccineerden, gevaccineerde, sneltests, vaccineren]
# 2407                           [tytsjerk, scheffer, lezersreacties, alsnog, viruswaarheid]
# ...                                                                                    ...
# 8277  [grensoverschrijdende, schimmelpenninck, europese, grensoverschrijdend, kritiekloos]
# 8317                                       [oneliners, ludieke, omtzigt, pitbull, snedige]
# 3251                        [toeslagenaffaire, schandvlek, kristie, fraudeurs, rechtshulp]
# 6224  [grensoverschrijdende, schimmelpenninck, europese, grensoverschrijdend, kritiekloos]
# 7534                              [bijstandsuitkeringen, 50pluss, maandloon, uurloon, mrd]
#
# [99 rows x 14 columns]

# %%
sample
# Out:
#     Similarity_Score  \
# 0           0.830725
# 1           0.826919
# 2           0.825910
# 3           0.693811
# 4           0.863585
# ..               ...
# 94          0.769193
# 95          0.738983
# 96          0.802753
# 97          0.769508
# 98          0.824292
#
#                                                                                                   Text1  \
# 0   Hoogste bestuursrechter liet forse steken vallen in affaire kinderopvangtoeslagen; De affaire ro...
# 1   Oud-vluchtelingen popelen om het parlement in te gaan; Op de kandidatenlijsten voor de Tweede Ka...
# 2   Verkiezingsdebat: Jetten zegt niet op wie hij stemt; D66-fractieleider Rob Jetten gaat stemmen o...
# 3   Ziekenhuisbezetting daalt met 55; De bezetting in de ziekenhuizen is de afgelopen dag afgenomen ...
# 4   Forum voor Democratie Jacht  op extra stemmen; Waar andere partijen zich nauwelijks op straat wa...
# ..                                                                                                  ...
# 94  Rechts wil minder verplicht betalen aan pensioen, links meer; Coalitiepartijen VVD en D66 willen...
# 95  Excuses van de koning voor slavernij zijn onafwendbaar; Slavernijverleden Ruttes weigering om ex...
# 96  Stelling 4: de rekening van de coronacrisis moet bij de best verdienende Nederlanders terechtkom...
# 97  Geweld bij antilockdowndemo in Dublin; Bij een demonstratie tegen de coronamaatregelen in Dublin...
# 98  Moet er meer in de zorg geïnvesteerd worden?; Hoekstra CDA zegt dat er meer ge nvesteerd moet wo...
#
#                                                                                                   Text2  \
# 0   Recht op reparatie van apparatuur komt steeds dichterbij; REPAIR CAF S Jeroen Groot en Caitlin S...
# 1   Partijen willen hogere lasten voor bedrijven, blijkt uit doorrekeningen CPB; Tien partijen kieze...
# 2   Milieuclubs niet echt blij met doorrekeningen; Milieuorganisaties zijn teleurgesteld over de ver...
# 3   Niet een lijsttrekker, maar een kiezer brengt Mark Rutte bij RTL in het nauw; Eerste TV-Debat He...
# 4   Niet een lijsttrekker, maar een kiezer brengt Mark Rutte bij RTL in het nauw; Eerste TV-Debat He...
# ..                                                                                                  ...
# 94  'Opvallend en veelzeggend dat VVD en CDA hier niet staan'; Een aantal partijen heeft op een pers...
# 95  De uitzending van 1 maart: Gasvrij duurder dan verwacht / IC's vol in Hoorn / Genomineerden Libr...
# 96  Gelijkspel in eerste grote tv-debat; Zondag gaf RTL de tv-aftrap van wellicht de kortste verkiez...
# 97  De Jonge: lijsttrekkers moeten in campagne behoedzaam zijn over corona ; Minister De Jonge van V...
# 98  De Jonge: lijsttrekkers moeten in campagne behoedzaam zijn over corona ; Minister de Jonge van V...
#
#      Group      Date1               Date2               Publisher1  \
# 0     high 2021-01-02 2021-01-02 00:00:00  Het Financieele Dagblad
# 1     high 2021-01-02 2021-01-05 00:00:00          NRC Handelsblad
# 2     high 2021-01-02 2021-01-05 00:00:00         Algemeen Dagblad
# 3   medium 2021-01-02 2021-01-05 00:00:00          NRC Handelsblad
# 4     high 2021-01-05 2021-01-05 00:00:00            De Volkskrant
# ..     ...        ...                 ...                      ...
# 94    high 2021-01-04 2021-01-05 00:00:00             De Telegraaf
# 95    high 2021-01-05 2021-01-05 00:00:00             De Telegraaf
# 96    high 2021-01-02 2021-01-03 22:29:27            De Volkskrant
# 97    high 2021-01-02 2021-01-05 00:00:00          NRC Handelsblad
# 98    high 2021-01-02 2021-01-05 00:00:00         Algemeen Dagblad
#
#           Publisher2      ID1      ID2  \
# 0              Trouw  3290695  3290567
# 1              Trouw  3287550  3287448
# 2      De Volkskrant  3287516  6290507
# 3   Algemeen Dagblad  3287538  3285627
# 4   Algemeen Dagblad  3285636  3285627
# ..               ...      ...      ...
# 94   NRC Handelsblad  3290653  3287398
# 95             Trouw  3285647  6290579
# 96             NU.nl  3287470  3290571
# 97   NRC Handelsblad  3287531  3287414
# 98   NRC Handelsblad  3287480  3287397
#
#                                                                                           proper_nouns1  \
# 0   Andr Bosman, VVD, Tweede Kamer, Raad van State, Bart Jan van Ettekoven, Herman Tjeenk Willink, R...
# 1               Tweede Kamer, Ellian, VVD, Ellian, advocaat van beroep, Afghanistan, Afshin Ellian, VVD
# 2   WNL, Rick Nieman, Sigrid Kaag, Nieman, Brinkman, CDA, WNL, VVD, Van Ark, PVV, Agema, CDA Pieter ...
# 3                                                                                              IC, RIVM
# 4   Forum voor Democratie, Forum voor Democratie, Ministerie kijkt, Urk, Baudet, Baudet, Baudet, Baudet
# ..                                                                                                  ...
# 94                       pensioen, D66, GroenLinks, Partij van de Arbeid, SP, D66, GroenLinks, PvdA, SP
# 95                                                             Slavernijverleden Ruttes, Tineke Bennema
# 96                                                                                Marijnissen, CDA, VVD
# 97                                                                         Geweld, Dublin, Leo Varadkar
# 98                                                                              Hoekstra CDA, SP, juist
#
#                                                                                           proper_nouns2  \
# 0                       REPAIR, CAF S Jeroen Groot, Philips, Leenman, Caf, Leenman, Repair Caf s, Caf s
# 1   CPB, SGP, CPB, VVD, CDA, D66, GroenLinks, SP, PvdA, ChristenUnie, SGP, PVV, Partij voor de Diere...
# 2   Milieuclubs, Kamers, CDA, GroenLinks, D66, PvdA, Greenpeace, D66, GroenLinks, PvdA, ChristenUnie...
# 3   Mark Rutte, RTL, Mark Rutte, Mark Rutte, Geert Wilders, PVV, Wopke Hoekstra, CDA, Sigrid, Lilian...
# 4   Mark Rutte, RTL, Mark Rutte, Mark Rutte, Geert Wilders, PVV, Wopke Hoekstra, CDA, Sigrid, Lilian...
# ..                                                                                                  ...
# 94                               CDA, CPB, PBL, CDA, CDA, Kamerlid Van Weyenberg, ambitieus, GroenLinks
# 95                                                  Friese Garijp, Noord-Holland Noord, Jan Nieuwenburg
# 96                       Wopke Hoekstra, CDA, Jesse Klaver, GroenLinks, Sigrid Kaag D66, Wopke Hoekstra
# 97                                                                            Jonge van Volksgezondheid
# 98                                                                            Jonge van Volksgezondheid
#
#                                                                                     keywords1  \
# 0          [overheidsinstantie, kinderopvangtoeslagen, ettekoven, dwingendrechtelijk, tjeenk]
# 1                        [afghanistan, rechtsgeleerde, verantwoordelijkheid, popelen, ellian]
# 2                              [leiderschapscrisis, omtzigt, verkiezingsdebat, lubbers, ruud]
# 3                                  [4605, besmettingen, ziekenhuisbezetting, coronapati, 525]
# 4                       [besmettingskansen, volmachtsstemmen, schielijk, volmachten, baudets]
# ..                                                                                        ...
# 94             [pensioenregeling, doorrekeningen, pensioenpremie, pensioenfondsen, werkenden]
# 95                          [onafwendbaar, ruttes, opofferen, slavernijverleden, amerikaanse]
# 96  [inkomensongelijkheid, marijnissen, belastingstelsel, verkiezingsprogramma, geprofiteerd]
# 97                  [ongeregeldheden, antilockdowndemo, wapenstokken, stephen, demonstranten]
# 98                          [obesitas, marijnissen, vraagstuk, debatteren, regeringspartijen]
#
#                                                                               keywords2
# 0              [verwarmingselement, reparateurs, koffiezetapparaat, reparateur, boiler]
# 1   [lastenverzwaring, doorrekeningen, verkiezingsprogramma, overheidsuitgaven, 50plus]
# 2               [greenpeace, nagestreefde, doorrekeningen, milieuclubs, klimaatakkoord]
# 3                [lijsttrekkersdebat, toeslagenaffaire, ontregelde, cijns, marijnissen]
# 4                [lijsttrekkersdebat, toeslagenaffaire, ontregelde, cijns, marijnissen]
# ..                                                                                  ...
# 94                            [rampspoed, doorrekeningen, reductie, overshoot, groener]
# 95                    [nieuwenburg, gasvrij, besmettingen, aardgasvrij, versoepelingen]
# 96       [mediaspektakels, stikstofuitstoot, stembussen, tegenstrevers, gevaccineerden]
# 97                             [besmettingscijfers, rtl, holland, versoepelingen, pati]
# 98                             [besmettingscijfers, rtl, holland, versoepelingen, pati]
#
# [99 rows x 14 columns]
